# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
penguins=sns.load_dataset("penguins")

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins["species"].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
penguins["island"].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
#scatterplot
sns.scatterplot(data=penguins,x="flipper_length_mm",y="body_mass_g")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.scatterplot(data=penguins,x="flipper_length_mm",y="body_mass_g",hue="species")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
#set_style
sns.set_style("darkgrid")
sns.scatterplot(data=penguins,x="flipper_length_mm",y="body_mass_g",hue="species")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.set_style("whitegrid")
sns.scatterplot(data=penguins,x="flipper_length_mm",y="body_mass_g",hue="island")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.set_style("ticks")
sns.scatterplot(data=penguins,x="flipper_length_mm",y="body_mass_g",hue="island")
sns.despine()

# %%
sns.set_style("ticks")
sns.scatterplot(data=penguins,x="flipper_length_mm",y="body_mass_g",hue="island")
sns.despine(left=True)

# %%
#set_context
sns.set_context("notebook")
sns.scatterplot(data=penguins,x="flipper_length_mm",y="body_mass_g",hue="species")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.set_context("poster")
sns.scatterplot(data=penguins,x="flipper_length_mm",y="body_mass_g",hue="species")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
#pallete type
sns.scatterplot(data=penguins,x="flipper_length_mm",y="body_mass_g",hue="species",palette="pastel")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.scatterplot(data=penguins,x="flipper_length_mm",y="body_mass_g",hue="species",palette="Set1")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
#Stripplot
sns.set_context("notebook")
sns.stripplot(data=penguins,x="species",y="body_mass_g",hue="island",jitter=True,dodge=True)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
#Swarmplot
sns.swarmplot(data=penguins,x="species",y="body_mass_g",hue="island")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.histplot(data=penguins,x="body_mass_g",hue="species",multiple="stack")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
#regplot
sns.regplot(data=penguins,x="flipper_length_mm",y="body_mass_g")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
#regplot
sns.regplot(data=penguins,x="flipper_length_mm",y="body_mass_g",scatter=False)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
#line plot
sns.lineplot(data=penguins,x="flipper_length_mm",y="body_mass_g",hue="species")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
#joint plt
sns.jointplot(data=penguins,x="flipper_length_mm",y="body_mass_g",hue="species")

# %%
sns.jointplot(data=penguins,x="flipper_length_mm",y="body_mass_g",hue="species",kind="kde")
#

# %%
#barplot
sns.barplot(data=penguins,x="species",y="body_mass_g",hue="island")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(data=penguins,x="species",y="body_mass_g",hue="island",estimator=np.median,palette=["pink","skyblue","orange"])
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
#Count plot
sns.countplot(data=penguins,x="species",hue="island")
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
#boxplot
sns.boxplot(data=penguins,x="species",y="body_mass_g",hue="island")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
#violin plot
sns.violinplot(data=penguins,x="species",y="body_mass_g",hue="island")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.violinplot(data=penguins,x="species",y="body_mass_g",hue="sex",split=True)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.violinplot(data=penguins,x="species",y="body_mass_g")
sns.swarmplot(data=penguins,x="species",y="body_mass_g",color="black",size=3)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
#kde plot
sns.kdeplot(data=penguins,x="flipper_length_mm",hue="species")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %%
sns.kdeplot(data=penguins,x="flipper_length_mm",hue="species",shade=True,fill=True)
# Out:
# /tmp/ipykernel_3439/3082786193.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=penguins,x="flipper_length_mm",hue="species",shade=True,fill=True)
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %%
#Heatmap
columns=["bill_length_mm","bill_depth_mm","flipper_length_mm","body_mass_g"]
correlations=penguins[columns].corr()
sns.heatmap(correlations,annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %%
#rug plot
sns.rugplot(data=penguins,x="flipper_length_mm",y="body_mass_g")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.rugplot(data=penguins,x="flipper_length_mm",y="body_mass_g",height=0.2,hue="species")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
#pair plot
sns.pairplot(data=penguins,hue="species")

# %%
sns.pairplot(data=penguins,diag_kind="kde")

# %%
#pair grid
g=sns.PairGrid(data=penguins,hue="species")
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)
g.map_diag(sns.histplot)
g.add_legend()
